# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading and Analysing Data

# %%
df1 = pd.read_csv('stroke.csv')

# %%
#skewness
df1['stroke'].skew()
# Out:
# 4.193284486071313

# %%
df1.shape
# Out:
# (5110, 12)

# %%
df1.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df1['stroke'].value_counts(normalize=True)
# Out:
# stroke
# 0    0.951272
# 1    0.048728
# Name: proportion, dtype: float64

# %%
df1['age'].describe()
# Out:
# count    5110.000000
# mean       43.226614
# std        22.612647
# min         0.080000
# 25%        25.000000
# 50%        45.000000
# 75%        61.000000
# max        82.000000
# Name: age, dtype: float64

# %%
df1['avg_glucose_level'].describe()
# Out:
# count    5110.000000
# mean      106.147677
# std        45.283560
# min        55.120000
# 25%        77.245000
# 50%        91.885000
# 75%       114.090000
# max       271.740000
# Name: avg_glucose_level, dtype: float64

# %%
df1['bmi'].describe()
# Out:
# count    4909.000000
# mean       28.893237
# std         7.854067
# min        10.300000
# 25%        23.500000
# 50%        28.100000
# 75%        33.100000
# max        97.600000
# Name: bmi, dtype: float64

# %% [markdown]
# ## Data Visualization

# %%
sns.distplot(df1['age'],
            bins = 10,
            kde = False);
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15444\966206028.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['age'],

# %%
sns.distplot(df1['avg_glucose_level'],
             bins = 10,
             kde = False);
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15444\1053016406.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['avg_glucose_level'],

# %%
sns.distplot(df1['bmi'],
             bins = 10,
             kde = False);
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15444\3618122642.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['bmi'],

# %%
sns.boxplot(y = df1['age'], color='lightgreen');

# %%
sns.boxplot(y = df1['bmi'], color='hotpink');

# %%
df1['gender'].value_counts()
# Out:
# gender
# Female    2994
# Male      2115
# Other        1
# Name: count, dtype: int64

# %%
#countlplot for gender
# sns.countplot( x = df1['gender']);
sns.countplot(x='gender', hue='gender', data=df1, palette='Set2')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
df1['hypertension'].value_counts()
# Out:
# hypertension
# 0    4612
# 1     498
# Name: count, dtype: int64

# %%
# Countplot for hypertension
# sns.countplot( x = df1['hypertension']);
sns.countplot(x='hypertension', hue='hypertension', data=df1, palette='Set2')
# Out:
# <Axes: xlabel='hypertension', ylabel='count'>

# %%
df1['heart_disease'].value_counts()
# Out:
# heart_disease
# 0    4834
# 1     276
# Name: count, dtype: int64

# %%
# Countplot for heart_disease
# sns.countplot( x = df1['heart_disease']);
sns.countplot(x='heart_disease', hue='heart_disease', data=df1, palette='Set2')
# Out:
# <Axes: xlabel='heart_disease', ylabel='count'>

# %%
df1['ever_married'].value_counts()
# Out:
# ever_married
# Yes    3353
# No     1757
# Name: count, dtype: int64

# %%
# sns.countplot( x = df1['ever_married']);
sns.countplot(x='ever_married', hue='ever_married', data=df1, palette='Set2')
# Out:
# <Axes: xlabel='ever_married', ylabel='count'>

# %%
df1['work_type'].value_counts()
# Out:
# work_type
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: count, dtype: int64

# %%
# Countplot for work_type
# sns.countplot( x = df1['work_type']);
sns.countplot(x='work_type', hue='work_type', data=df1, palette='Set2')
# Out:
# <Axes: xlabel='work_type', ylabel='count'>

# %%
df1['Residence_type'].value_counts()
# Out:
# Residence_type
# Urban    2596
# Rural    2514
# Name: count, dtype: int64

# %%
# Countplot for Residence_type
# sns.countplot( x = df1['Residence_type']);
sns.countplot(x='Residence_type', hue='Residence_type', data=df1, palette='Set3')
# Out:
# <Axes: xlabel='Residence_type', ylabel='count'>

# %%
df1['smoking_status'].value_counts()
# Out:
# smoking_status
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: count, dtype: int64

# %%
# Countplot for smoking_status
# sns.countplot( x = df1['smoking_status']);
sns.countplot(x='smoking_status', hue='smoking_status', data=df1, palette='Set1')
# Out:
# <Axes: xlabel='smoking_status', ylabel='count'>

# %%
df1['stroke'].value_counts()
# Out:
# stroke
# 0    4861
# 1     249
# Name: count, dtype: int64

# %%
# Countplot for stroke
# sns.countplot( x = df1['stroke']);
sns.countplot(x='stroke', hue='stroke', data=df1, palette='Set2')
# Out:
# <Axes: xlabel='stroke', ylabel='count'>

# %%
# Paired boxplot of stroke vs age
sns.boxplot(x = 'stroke',
            y = 'age',
            data = df1,
            color='skyblue');

# %%
# Paired boxplot of stroke vs avg_glucose_level
sns.boxplot(x = 'stroke',
            y = 'avg_glucose_level',
            data = df1,
            color='lightgreen');

# %%
# Paired boxplot of stroke vs bmi
sns.boxplot(x = 'stroke',
            y = 'bmi',
            data = df1,
            color='coral');

# %%
# Stacked Bar plot for stroke vs gender
pd.crosstab(df1['stroke'],
            df1['gender'],
            normalize='index').plot(kind='bar', stacked=True);

# %%
# Stacked Bar plot for stroke vs hypertension
pd.crosstab(df1['stroke'],
            df1['hypertension'],
            normalize='index').plot(kind='bar', stacked=True);

# %%
# Stacked Bar plot for stroke vs heart_disease
pd.crosstab(df1['stroke'],
            df1['heart_disease'],
            normalize='index').plot(kind='bar', stacked=True);

# %%
# Stacked Bar plot for stroke vs ever_married
pd.crosstab(df1['stroke'],
            df1['ever_married'],
            normalize='index').plot(kind='bar', stacked=True);

# %%
# Stacked Bar plot for stroke vs work_type
ax = pd.crosstab(df1['stroke'],
            df1['work_type'],
            normalize='index').plot(kind='bar', stacked=True)
ax.legend(loc='upper right', bbox_to_anchor=(1.4, 0.8), shadow=True, ncol=1);

# %%
# Stacked Bar plot for stroke vs Residence_type
ax = pd.crosstab(df1['stroke'],
            df1['Residence_type'],
            normalize='index').plot(kind='bar', stacked=True);
ax.legend(loc='upper right', bbox_to_anchor=(1.3, 0.8), shadow=True, ncol=1);

# %%
# Stacked Bar plot for stroke vs smoking_status
ax = pd.crosstab(df1['stroke'],
            df1['smoking_status'],
            normalize='index').plot(kind='bar', stacked=True);
ax.legend(loc='upper right', bbox_to_anchor=(1.3, 0.8), shadow=True, ncol=1);

# %%
## Collect numerical variables in a dataframe
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

numerical_df = df1.select_dtypes(include=numerics)

# Remmove the Y variable
numerical_df.drop('stroke', axis=1, inplace=True)

# %%
# Check correlation among numerical independent variables using correlation matrix
cor = numerical_df.corr()
cor
# Out:
#                          id       age  hypertension  heart_disease  \
# id                 1.000000  0.003538      0.003550      -0.001296
# age                0.003538  1.000000      0.276398       0.263796
# hypertension       0.003550  0.276398      1.000000       0.108306
# heart_disease     -0.001296  0.263796      0.108306       1.000000
# avg_glucose_level  0.001092  0.238171      0.174474       0.161857
# bmi                0.003084  0.333398      0.167811       0.041357
#
#                    avg_glucose_level       bmi
# id                          0.001092  0.003084
# age                         0.238171  0.333398
# hypertension                0.174474  0.167811
# heart_disease               0.161857  0.041357
# avg_glucose_level           1.000000  0.175502
# bmi                         0.175502  1.000000

# %%
# View heat map of the correlation matrix
sns.heatmap(cor, annot = True,cmap='Blues');

# %%
#Highly correlated X variables
c = cor.abs()

# Unstack the correlation matrix
s = c.unstack()

#Filter to exclude values of 1
s = s[s != 1]

# Sort descending to find the highly correlated variables
so = s.sort_values(kind="quicksort", ascending=False)[:10]
so
# Out:
# age                bmi                  0.333398
# bmi                age                  0.333398
# hypertension       age                  0.276398
# age                hypertension         0.276398
#                    heart_disease        0.263796
# heart_disease      age                  0.263796
# age                avg_glucose_level    0.238171
# avg_glucose_level  age                  0.238171
#                    bmi                  0.175502
# bmi                avg_glucose_level    0.175502
# dtype: float64
